# %%
# %sql
CREATE or replace VIEW MKTSEG_BUILD_vw as
select
customer.c_custkey,
customer.c_name,
customer.c_address,
customer.c_phone,
customer.c_acctbal,
customer.c_mktsegment,
customer.c_comment,
nation.n_name,
nation.n_comment,
region.r_name,
region.r_comment,
orders.o_orderkey,
orders.o_orderstatus,
orders.o_totalprice,
orders.o_orderdate,
orders.o_orderpriority,
orders.o_clerk,
orders.o_shippriority,
orders.o_comment,
lineitem.l_linenumber,
lineitem.l_quantity,
lineitem.l_extendedprice,
lineitem.l_discount,
lineitem.l_tax,
lineitem.l_returnflag,
lineitem.l_linestatus,
lineitem.l_shipdate,
lineitem.l_commitdate,
lineitem.l_receiptdate,
lineitem.l_shipinstruct,
lineitem.l_shipmode,
lineitem.l_comment,
part.p_name,
part.p_mfgr,
part.p_brand,
part.p_type,
part.p_size,
part.p_container,
part.p_retailprice,
part.p_comment,
partsupp.ps_availqty,
partsupp.ps_supplycost,
partsupp.ps_comment,
supplier.s_name,
supplier.s_address,
supplier.s_nationkey,
supplier.s_phone,
supplier.s_acctbal,
supplier.s_comment
from samples.tpch.customer
full join samples.tpch.nation on samples.tpch.customer.c_nationkey = samples.tpch.nation.n_nationkey
full join samples.tpch.region on samples.tpch.nation.n_regionkey = samples.tpch.region.r_regionkey
full join samples.tpch.orders on samples.tpch.customer.c_custkey = samples.tpch.orders.o_custkey
full join samples.tpch.lineitem on samples.tpch.orders.o_orderkey = samples.tpch.lineitem.l_orderkey
full join samples.tpch.part on samples.tpch.lineitem.l_partkey = samples.tpch.part.p_partkey
full join samples.tpch.partsupp on samples.tpch.lineitem.l_partkey = samples.tpch.partsupp.ps_partkey
full join samples.tpch.supplier on samples.tpch.lineitem.l_suppkey = samples.tpch.supplier.s_suppkey
where upper(customer.c_mktsegment) = 'BUILDING'

# %%
# %sql
SELECT * FROM MKTSEG_BUILD_vw

# %%
# %sql
CREATE OR REPLACE TABLE MKTSEG_BUILD (
  c_custkey	bigint	COMMENT 'Customer Key',
  c_name	string	COMMENT 'Customer Name',
  c_address	string	COMMENT 'Customer Address',
  c_phone	string	COMMENT 'Phone Number',
  c_acctbal	decimal(18,2)	COMMENT 'Account Balance',
  c_mktsegment	string	COMMENT 'Market Segment',
  c_comment	string	COMMENT 'Customer Comment',
  n_name	string	COMMENT 'Nation Name',
  n_comment	string	COMMENT 'Nation Comment',
  r_name	string	COMMENT 'Region Name',
  r_comment	string	COMMENT 'Region Comment',
  o_orderkey	bigint	COMMENT 'Order Key',
  o_orderstatus	string	COMMENT 'Order Status',
  o_totalprice	decimal(18,2)	COMMENT 'Total Price',
  o_orderdate	date	COMMENT 'Order Date',
  o_orderpriority	string	COMMENT 'Order Priority',
  o_clerk	string	COMMENT 'Clerk',
  o_shippriority	int	COMMENT 'Ship Priority',
  o_comment	string	COMMENT 'Order Comment',
  l_linenumber	int	COMMENT 'Line Number',
  l_quantity	decimal(18,2)	COMMENT 'Quantity',
  l_extendedprice	decimal(18,2)	COMMENT 'Extended Price',
  l_discount	decimal(18,2)	COMMENT 'Discount',
  l_tax	decimal(18,2)	COMMENT 'Tax',
  l_returnflag	string	COMMENT 'Return Flag',
  l_linestatus	string	COMMENT 'Line Status',
  l_shipdate	date	COMMENT 'Ship Date',
  l_commitdate	date	COMMENT 'Commit Date',
  l_receiptdate	date	COMMENT 'Receipt Date',
  l_shipinstruct	string	COMMENT 'Ship Instruction',
  l_shipmode	string	COMMENT 'Ship Mode',
  l_comment	string	COMMENT 'Line Comment',
  p_name	string	COMMENT 'Part Name',
  p_mfgr	string	COMMENT 'Manufacturer',
  p_brand	string	COMMENT 'Brand',
  p_type	string	COMMENT 'Type',
  p_size	int	COMMENT 'Size',
  p_container	string	COMMENT 'Container',
  p_retailprice	decimal(18,2)	COMMENT 'Retail Price',
  p_comment	string	COMMENT 'Part Comment',
  ps_availqty	int	COMMENT 'Available Quantity',
  ps_supplycost	decimal(18,2)	COMMENT 'Supply Cost',
  ps_comment	string	COMMENT 'Part Supplier Comment',
  s_name	string	COMMENT 'Supplier Name',
  s_address	string	COMMENT 'Supplier Address',
  s_nationkey	bigint	COMMENT 'Supplier Nation Key',
  s_phone	string	COMMENT 'Supplier Phone',
  s_acctbal	decimal(18,2)	COMMENT 'Supplier Account Balance',
  s_comment	string	COMMENT 'Supplier Comment'
)
